# %%
import pandas as pd
import altair as alt
from models import IngredientMatcher
from models import SeasonalityChecker

# Chemin du dossier contenant les fichiers CSV


chemin = 'data/dico_all_month_ingredient'


# Chargement des données pour chaque mois
dico_all_month_ingredient = {}

for i in range(1, 13):
    # Lecture du CSV en gardant l'ordre d'origine
    dico_all_month_ingredient[i] = pd.read_csv(chemin + str(i) + '.csv')
    dico_all_month_ingredient[i].columns = ['ingredients', 'apparences', 'freq']
    
dico_all_month_ingredient_test={}
for i in range(1, 13):
    dico_all_month_ingredient_test[i]= dico_all_month_ingredient[i]
    dico_all_month_ingredient_test[i] = dico_all_month_ingredient_test[i].set_index('ingredients')
    dico_all_month_ingredient_test[i].index.name = None  
    


df_recipes_tokenised = pd.read_json("data/data_recipes_tokenised.json", orient="records")
df_recipes_tokenised['submitted'] = pd.to_datetime(df_recipes_tokenised['submitted'])

# %%
matcher = IngredientMatcher(df_recipes_tokenised,dico_all_month_ingredient_test)
matcher.ingredient_std('pepper')
# Out:
# (array([[0.99842718],
#         [0.99389655],
#         [0.95251502],
#         [0.9674355 ],
#         [1.        ],
#         [0.99695624],
#         [0.98360378],
#         [0.99697003],
#         [0.97271003],
#         [0.93162498],
#         [0.9138315 ],
#         [0.83352467]]),
#  [np.float64(0.04715430542857913), 12])

# %%
result_recipes,resul_ingredient=matcher.seasonal_recommendations_1('peach',3)[0],matcher.seasonal_recommendations_1('peach',3)[1]
result_recipes,resul_ingredient
# Out:
# ([20746, 64945, 113826, 115463, 132855], ['yogurt', 'strawberry', 'blueberry'])

# %%
df_recipes_tokenised.loc[result_recipes,'name'].reset_index(drop=True)
# Out:
# 0                booberry yogo smoothie
# 1                 finnish berry dessert
# 2     one muffin recipe7 different ways
# 3               organic yogurt smoothie
# 4    red  white  and blueberry smoothie
# Name: name, dtype: object

# %%
dico_fraise = matcher.ingredient_match('strawberry',5)
dico_fraise
sorted_dict = dict(sorted(dico_fraise.items(), key=lambda item: item[1], reverse=True))
sorted_dict
# Out:
# {'strawberry': 588,
#  'sugar': 417,
#  'juice': 199,
#  'cream': 155,
#  'water': 136,
#  'salt': 119,
#  'butter': 112,
#  'cheese': 110,
#  'flour': 91,
#  'milk': 90,
#  'extract': 88,
#  'egg': 88,
#  'oil': 63,
#  'banana': 60,
#  'powder': 55,
#  'yogurt': 55,
#  'blueberry': 47,
#  'cornstarch': 47,
#  'cinnamon': 45,
#  'vinegar': 45,
#  'honey': 43,
#  'vanilla': 39,
#  'pepper': 37,
#  'soda': 37,
#  'mix': 35,
#  'gelatin': 31,
#  'orange': 31,
#  'syrup': 31,
#  'onion': 27,
#  'of': 26,
#  'cube': 26,
#  'leaf': 25,
#  'liqueur': 25,
#  'whip': 25,
#  'raspberry': 25,
#  'pineapple': 24,
#  'almond': 23,
#  'topping': 23,
#  'fruit': 22,
#  'rhubarb': 22,
#  'grape': 22,
#  'white': 21,
#  'concentrate': 21,
#  'wine': 20,
#  'walnut': 20,
#  'coconut': 18,
#  'seed': 18,
#  'shell': 17,
#  'apple': 17,
#  'lettuce': 17,
#  'pecan': 17,
#  'cake': 16,
#  'ice': 16,
#  'peach': 15,
#  'green': 15,
#  'lemon': 15,
#  'chip': 15,
#  'substitute': 14,
#  'jam': 14,
#  'mustard': 14,
#  'kiwi': 14,
#  'mango': 14,
#  'chunk': 14,
#  'buttermilk': 13,
#  'zest': 13,
#  'rum': 13,
#  'chocolate': 13,
#  'crust': 13,
#  'dessert': 13,
#  'clove': 12,
#  'sprig': 12,
#  'cantaloupe': 12,
#  'crumb': 12,
#  'slice': 12,
#  'spinach': 12,
#  'oat': 11,
#  'watermelon': 11,
#  'mint': 11,
#  'nut': 11,
#  'melon': 10,
#  'bread': 10,
#  'marnier': 10,
#  'margarine': 10,
#  'ginger': 10,
#  'yolk': 9,
#  'rind': 9,
#  'half-and-half': 9,
#  'sauce': 9,
#  'pudding': 8,
#  'blackberry': 8,
#  'nutmeg': 8,
#  'vodka': 8,
#  'coloring': 8,
#  'avocado': 7,
#  'preserve': 7,
#  'papaya': 7,
#  'half': 7,
#  'mayonnaise': 7,
#  'applesauce': 7,
#  'sec': 7,
#  'jelly': 7,
#  'tequila': 7,
#  'cucumber': 6,
#  'basil': 6,
#  'dressing': 6,
#  'shortening': 6,
#  'square': 6,
#  'glaze': 6,
#  'champagne': 6,
#  'stick': 5,
#  'peel': 5,
#  'brandy': 5,
#  'cookie': 5,
#  'chicken': 5,
#  'cracker': 5,
#  'cocoa': 5,
#  'celery': 5,
#  'nectar': 5,
#  'pear': 5,
#  'fraiche': 5,
#  'paprika': 5,
#  'beverage': 5,
#  'pretzel': 5,
#  'ale': 5,
#  'ball': 4,
#  'spray': 4,
#  'tartar': 4,
#  'marshmallow': 4,
#  'filling': 4,
#  'apricot': 4,
#  'granular': 4,
#  'dough': 4,
#  'tortilla': 4,
#  'lime': 4,
#  'pectin': 4,
#  'oatmeal': 4,
#  'raisin': 4,
#  'tapioca': 4,
#  'hazelnut': 3,
#  'poundcake': 3,
#  'sheet': 3,
#  'sherbet': 3,
#  'sprinkle': 3,
#  'pistachio': 3,
#  'skewer': 3,
#  'bag': 3,
#  'twinky': 3,
#  'lite': 3,
#  'cherry': 3,
#  'section': 3,
#  'grapefruit': 3,
#  'chive': 3,
#  'soymilk': 3,
#  'garlic': 3,
#  'spread': 3,
#  'flower': 3,
#  'bean': 3,
#  'lemonade': 3,
#  'blossom': 2,
#  'cereal': 2,
#  'piece': 2,
#  'croissant': 2,
#  'ladyfinger': 2,
#  'free': 2,
#  'coffee': 2,
#  'bar': 2,
#  'nectarine': 2,
#  'pod': 2,
#  'rib': 2,
#  'scallion': 2,
#  'germ': 2,
#  'bran': 2,
#  'cabbage': 2,
#  'cranberry': 2,
#  'rice': 2,
#  'kirsch': 2,
#  'tarragon': 2,
#  'flake': 2,
#  'cilantro': 2,
#  'roll': 2,
#  'cocktail': 2,
#  'tidbit': 2,
#  'grenadine': 2,
#  'cardamom': 2,
#  'plum': 2,
#  'berry': 2,
#  'wafer': 2,
#  'curd': 2,
#  'carrot': 2,
#  'breast': 2,
#  'tangerine': 2,
#  'shallot': 2,
#  'bit': 2,
#  'pastry': 2,
#  'wedge': 2,
#  'puree': 2,
#  'muesli': 2,
#  'steak': 2,
#  'allspice': 2,
#  'anise': 2,
#  'amaretti': 2,
#  'asparagu': 2,
#  'cashew': 2,
#  'schnapp': 2,
#  'peppercorn': 2,
#  'yeast': 2,
#  'broth': 2,
#  'olive': 1,
#  'pea': 1,
#  'vinaigrette': 1,
#  'paste': 1,
#  'guava': 1,
#  'tomato': 1,
#  'liquor': 1,
#  'pie': 1,
#  'muffin': 1,
#  'chile': 1,
#  'tenderloin': 1,
#  'rod': 1,
#  'candy': 1,
#  'kale': 1,
#  'drink': 1,
#  'jello': 1,
#  'fig': 1,
#  'arrowroot': 1,
#  'chestnut': 1,
#  'cognac': 1,
#  'carambola': 1,
#  'honeydew': 1,
#  'spear': 1,
#  'crouton': 1,
#  'pitaya': 1,
#  'jalapeno': 1,
#  'lingonberry': 1,
#  'seasoning': 1,
#  'nutella': 1,
#  'heart': 1,
#  'horseradish': 1,
#  'mushroom': 1,
#  'kahlua': 1,
#  'challah': 1,
#  'woodruff': 1,
#  'wax': 1,
#  'pancake': 1,
#  'biscuit': 1,
#  'endive': 1,
#  'baguette': 1,
#  'peanut': 1,
#  'pomegranate': 1,
#  'corn': 1,
#  'fillet': 1,
#  'chervil': 1,
#  'shortcake': 1,
#  'shaving': 1,
#  'sherry': 1,
#  'shrimp': 1,
#  'oregano': 1,
#  'parsley': 1,
#  'watercres': 1,
#  'arugula': 1,
#  'palm': 1,
#  'mace': 1,
#  'crepe': 1,
#  'radish': 1,
#  'feta': 1,
#  'crisco': 1,
#  'sprite': 1,
#  'granola': 1,
#  'mascarpone': 1,
#  '43': 1,
#  'molass': 1,
#  'jicama': 1,
#  'sweetener': 1,
#  'mold': 1,
#  'tuna': 1,
#  'rosemary': 1,
#  'rocket': 1,
#  'hole': 1,
#  'amaretto': 1,
#  'thyme': 1,
#  'sorbet': 1,
#  'jell-o': 1,
#  'starch': 1,
#  'port': 1,
#  'marmalade': 1,
#  'waffle': 1,
#  'pulp': 1,
#  'acid': 1}

# %%
for ing in sorted_dict:
    print(ing,sorted_dict[ing],matcher.ingredient_std(ing)[1][0])
# Out:
# strawberry 588 0.22421985780472514
# sugar 417 0.0544824301336608
# juice 199 0.09233371077557029
# cream 155 0.024939091897317224
# water 136 0.01141076080168744
# salt 119 0.011738825051728284
# butter 112 0.0627002377535759
# cheese 110 0.03955852535544898
# flour 91 0.06876675126122411
# milk 90 0.0483523801299309
# extract 88 0.09099634838003887
# egg 88 0.04836014712439762
# oil 63 0.05777852891153815
# banana 60 0.09746149427346104
# powder 55 0.03526060460995081
# yogurt 55 0.15450809369808619
# blueberry 47 0.223182468777298
# cornstarch 47 0.0669399305769672
# cinnamon 45 0.09814272987972955
# vinegar 45 0.11024121133348538
# honey 43 0.09136824362615338
# vanilla 39 0.11238007984291588
# pepper 37 0.04715430542857913
# soda 37 0.0910407159679644
# mix 35 0.0782871069062026
# gelatin 31 0.08872086704290406
# orange 31 0.09516647198464863
# syrup 31 0.10308446185822538
# onion 27 0.03550256091824871
# of 26 0.0751480946538925
# cube 26 0.08175626678054307
# leaf 25 0.06604458577824955
# liqueur 25 0.1429358287352387
# whip 25 0.06738044326481961
# raspberry 25 0.2037554463432489
# pineapple 24 0.11621388027749043
# almond 23 0.05902304406718822
# topping 23 0.10724514491407716
# fruit 22 0.1365812288682599
# rhubarb 22 0.2861542525165221
# grape 22 0.13274023994238257
# white 21 0.06168292109490119
# concentrate 21 0.09029331092274746
# wine 20 0.054649036891822454
# walnut 20 0.1180363720909363
# coconut 18 0.09573520661723459
# seed 18 0.06565495111632302
# shell 17 0.07653138221918881
# apple 17 0.1374632463891844
# lettuce 17 0.1347584541808023
# pecan 17 0.15455303313456373
# cake 16 0.17126972116379344
# ice 16 0.20678919983584365
# peach 15 0.2390975962368403
# green 15 0.16381898642939224
# lemon 15 0.12294709341079448
# chip 15 0.11064222926954127
# substitute 14 0.12721376911172294
# jam 14 0.11870263863087836
# mustard 14 0.07763143285896063
# kiwi 14 0.2691601115102902
# mango 14 0.23303567095048988
# chunk 14 0.17105308795341953
# buttermilk 13 0.06192750497423089
# zest 13 0.09281235760524184
# rum 13 0.18252302721629257
# chocolate 13 0.1265093050222694
# crust 13 0.07330744164068713
# dessert 13 0.22563797881493022
# clove 12 0.04746470247925688
# sprig 12 0.1275017750900081
# cantaloupe 12 0.3096326754512123
# crumb 12 0.07414181211595967
# slice 12 0.10947286443529372
# spinach 12 0.08919208761793385
# oat 11 0.06306562011770063
# watermelon 11 0.3170122373959072
# mint 11 0.2055923699386991
# nut 11 0.07138689699366521
# melon 10 0.2592118984031303
# bread 10 0.04273322177396877
# marnier 10 0.18751668016548917
# margarine 10 0.0841441177188366
# ginger 10 0.044950314380613476
# yolk 9 0.09336016174133255
# rind 9 0.10759881013075641
# half-and-half 9 0.1022689781798261
# sauce 9 0.0474324696131866
# pudding 8 0.10799587003513816
# blackberry 8 0.23518200522683752
# nutmeg 8 0.13827628203065045
# vodka 8 0.13781024156804367
# coloring 8 0.14291511170406787
# avocado 7 0.16762444823548875
# preserve 7 0.13142766868145
# papaya 7 0.21622112904928753
# half 7 0.07068436249173583
# mayonnaise 7 0.0929518102459257
# applesauce 7 0.10541122972880346
# sec 7 0.2043876683291669
# jelly 7 0.10389864896086583
# tequila 7 0.22830294548796465
# cucumber 6 0.20555163227453035
# basil 6 0.09285523058131312
# dressing 6 0.14124325049786665
# shortening 6 0.12402186592008707
# square 6 0.18856563770253731
# glaze 6 0.22818417757993056
# champagne 6 0.198808440445343
# stick 5 0.15661785689345595
# peel 5 0.06788522543851781
# brandy 5 0.14900343627213716
# cookie 5 0.13316877568419389
# chicken 5 0.07827797952954882
# cracker 5 0.10777119856044114
# cocoa 5 0.1022491723160967
# celery 5 0.0900671172997508
# nectar 5 0.136409157453402
# pear 5 0.15681735898466642
# fraiche 5 0.18816809173858368
# paprika 5 0.04772615015808288
# beverage 5 0.18107211474841864
# pretzel 5 0.19831034295276603
# ale 5 0.16290043699243142
# ball 4 0.155319910756092
# spray 4 0.06733775419158405
# tartar 4 0.14092455242645582
# marshmallow 4 0.13809963255858754
# filling 4 0.09909852830505907
# apricot 4 0.1245325798859803
# granular 4 0.12010455675069827
# dough 4 0.07951195264108975
# tortilla 4 0.08954544871546925
# lime 4 0.1802629860069994
# pectin 4 0.1916213351332744
# oatmeal 4 0.1268107776187457
# raisin 4 0.06718644801361785
# tapioca 4 0.22473015056902187
# hazelnut 3 0.17114707421879252
# poundcake 3 0.26007932264119754
# sheet 3 0.17985917783345073
# sherbet 3 0.20836024539469392
# sprinkle 3 0.21418963200662067
# pistachio 3 0.18734134403789798
# skewer 3 0.21920069672476206
# bag 3 0.14725422429514393
# twinky 3 0.24508594725821903
# lite 3 0.23672129420313903
# cherry 3 0.1536963349543398
# section 3 0.19065991292123993
# grapefruit 3 0.19504003121451455
# chive 3 0.09484883645935288
# soymilk 3 0.14291281346479903
# garlic 3 0.057572389287287855
# spread 3 0.13344762680041422
# flower 3 0.29460090710698583
# bean 3 0.060785355858773045
# lemonade 3 0.21284218392793103
# blossom 2 0.26200193689912954
# cereal 2 0.12179782819962455
# piece 2 0.11784664072330099
# croissant 2 0.1843572710206882
# ladyfinger 2 0.22439003150263268
# free 2 0.16880052976377263
# coffee 2 0.11486571044747984
# bar 2 0.1379079432014609
# nectarine 2 0.2543818380316931
# pod 2 0.11480867312508063
# rib 2 0.09301196881182236
# scallion 2 0.11071872356178107
# germ 2 0.1391423391084328
# bran 2 0.13456178889428624
# cabbage 2 0.078276758463248
# cranberry 2 0.2276422753116048
# rice 2 0.03653533132676469
# kirsch 2 0.24688411396173612
# tarragon 2 0.12432153140172156
# flake 2 0.04801182347119261
# cilantro 2 0.13351585084261908
# roll 2 0.0911753410715991
# cocktail 2 0.15828726643125987
# tidbit 2 0.16102304193929085
# grenadine 2 0.2320941601356047
# cardamom 2 0.09964748960021647
# plum 2 0.2120919018149391
# berry 2 0.1878597958658068
# wafer 2 0.17100799127981992
# curd 2 0.19692393774756795
# carrot 2 0.0933243788891903
# breast 2 0.08892148113461806
# tangerine 2 0.2641472618853188
# shallot 2 0.07486067914552655
# bit 2 0.09922326977248655
# pastry 2 0.1313835753075516
# wedge 2 0.1448564898436075
# puree 2 0.20839767695025657
# muesli 2 0.2304438981292905
# steak 2 0.10326466406668308
# allspice 2 0.14293984922302155
# anise 2 0.15649712253045833
# amaretti 2 0.2691826351991323
# asparagu 2 0.2142754264909958
# cashew 2 0.12489375497048377
# schnapp 2 0.19152696150374154
# peppercorn 2 0.08477945893021327
# yeast 2 0.0658034672982922
# broth 2 0.1262257109494163
# olive 1 0.09780307053705982
# pea 1 0.06490437191067944
# vinaigrette 1 0.20248760641474728
# paste 1 0.05756461182641789
# guava 1 0.2756377053075087
# tomato 1 0.08806517542468355
# liquor 1 0.19902457567211382
# pie 1 0.18123180065155658
# muffin 1 0.1473018165483798
# chile 1 0.1170046025822206
# tenderloin 1 0.07558509544118984
# rod 1 0.2086369707876903
# candy 1 0.20668677883708314
# kale 1 0.21394735183101538
# drink 1 0.2733678648504397
# jello 1 0.2510262583188563
# fig 1 0.16016367532268858
# arrowroot 1 0.20800085732566392
# chestnut 1 0.07972786277328356
# cognac 1 0.19775779619427017
# carambola 1 0.06400051625307031
# honeydew 1 0.2552623313770835
# spear 1 0.20518106447802512
# crouton 1 0.13543194038814968
# pitaya 1 0.0
# jalapeno 1 0.11622893914680238
# lingonberry 1 0.28225058711338596
# seasoning 1 0.07262731235303403
# nutella 1 0.2519402852303445
# heart 1 0.10913236992141778
# horseradish 1 0.09738426476536599
# mushroom 1 0.06656339495769377
# kahlua 1 0.16990124487685873
# challah 1 0.21582710752034978
# woodruff 1 0.0
# wax 1 0.3033528903386985
# pancake 1 0.22777387009849814
# biscuit 1 0.14980352296193739
# endive 1 0.19423273300095942
# baguette 1 0.09245230601655909
# peanut 1 0.10550478529054302
# pomegranate 1 0.2638948890748579
# corn 1 0.08270360861901474
# fillet 1 0.1137601218840649
# chervil 1 0.20968421213023586
# shortcake 1 0.2378139382922438
# shaving 1 0.20306047143854417
# sherry 1 0.08199789808335096
# shrimp 1 0.12071121380148352
# oregano 1 0.08904955529257719
# parsley 1 0.0407773597989039
# watercres 1 0.21235567904399155
# arugula 1 0.18091735416577523
# palm 1 0.21434871969590544
# mace 1 0.14530711968046078
# crepe 1 0.28062385836543674
# radish 1 0.1869284500040588
# feta 1 0.1395969897911332
# crisco 1 0.14277659870418788
# sprite 1 0.20642496300445004
# granola 1 0.2717776143361167
# mascarpone 1 0.30702323943752036
# 43 1 0.0658704221373081
# molass 1 0.0990127625434926
# jicama 1 0.2215068762304989
# sweetener 1 0.2111342995449828
# mold 1 0.038999940684500245
# tuna 1 0.11598768448458492
# rosemary 1 0.0849517468616934
# rocket 1 0.25613931145536195
# hole 1 0.08906222195859592
# amaretto 1 0.16445655851762267
# thyme 1 0.051919185705966216
# sorbet 1 0.2655718343815719
# jell-o 1 0.21663664397878568
# starch 1 0.2048861839923357
# port 1 0.22849314784692681
# marmalade 1 0.12132786880074625
# waffle 1 0.2292911605033914
# pulp 1 0.1902971512250099
# acid 1 0.2653657870237966

# %%
matcher.ingredient_std('salt')[1][0]
# Out:
# np.float64(0.011738825051728284)

# %%
dico_all_month_ingredient[1]
# Out:
#          ingredients  apparences        freq
# 0    nbre_ingredient    153802.0  911.959680
# 1        nbre_recipe     16865.0  100.000000
# 2             pepper      9024.0   53.507264
# 3               salt      7599.0   45.057812
# 4              onion      6189.0   36.697302
# ..               ...         ...         ...
# 927            cassi         1.0    0.005929
# 928         crawfish         1.0    0.005929
# 929             melt         1.0    0.005929
# 930          bagoong         1.0    0.005929
# 931            lopez         1.0    0.005929
#
# [932 rows x 3 columns]

# %%
seasoner_checker = SeasonalityChecker(dico_all_month_ingredient_test)
seasoner_checker.is_seasonal('salt')
matcher.ingredient_std('salt')
# Out:
# (array([[0.99485718],
#         [0.96548664],
#         [0.98108363],
#         [0.98181934],
#         [0.98355527],
#         [0.99024086],
#         [0.95638211],
#         [0.98227771],
#         [0.97219591],
#         [1.        ],
#         [0.98343935],
#         [0.99014742]]),
#  [np.float64(0.011738825051728284), 12])

# %%
def ingredient_score(ingredient):

    std_result = matcher.ingredient_std(ingredient)
    
    if isinstance(std_result[1], (list, tuple)) and len(std_result[1]) > 1:
        nbre_month = std_result[1][1]
    else:
        nbre_month = std_result[1] 

    if nbre_month < 12:
        return nbre_month
        
    else:
        return std_result[1][0]
    
ingredient_score('fefefeffe')
# Out:
# 0

# %%
vinegare_score=[]
for i in range (1,13):
    dico_all_month_ingredient[i]['score']  =  dico_all_month_ingredient[i].ingredients.apply(lambda x : ingredient_score(x))
    dico_all_month_ingredient[i].iloc[:1].score.values
    vinegare_score.append(  dico_all_month_ingredient[i][dico_all_month_ingredient[i].score > 0.1].iloc[:1].score.values)

# %%
vinegare_score ,max(vinegare_score)
# Out:
# ([array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11024121]),
#   array([0.11238008])],
#  array([0.11238008]))

# %%
selected_month = 3
top = 10
df_selected_month = dico_all_month_ingredient[selected_month]
df_selected_month
#df_selected_month = df_selected_month[df_selected_month.score > 0.1]
df_selected_month.iloc[:top]
# Out:
#        ingredients  apparences        freq     score
# 0  nbre_ingredient    143712.0  900.789771  0.006831
# 1      nbre_recipe     15954.0  100.000000  0.000000
# 2           pepper      8144.0   51.046759  0.047154
# 3             salt      7089.0   44.433998  0.011739
# 4            sugar      6029.0   37.789896  0.054482
# 5              oil      5525.0   34.630814  0.057779
# 6            onion      5450.0   34.160712  0.035503
# 7           cheese      5258.0   32.957252  0.039559
# 8           butter      4864.0   30.487652  0.062700
# 9            flour      3931.0   24.639589  0.068767

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

plt.figure(figsize=(10, 6))
sns.histplot(df_selected_month['score'], bins=10, kde=True, color='skyblue')
plt.title('Distribution des scores')
plt.xlabel('Score')
plt.ylabel('Fréquence')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
